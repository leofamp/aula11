# %% [markdown]
# <a href="https://colab.research.google.com/github/leofamp/aula11/blob/main/aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lista = (1,2,3,4,5,1,1,1,1,1,1)#lista que não pode ser modificada
#() - cria uma tupla - lista que não pode ser modificada
#{} - cria uma Dicionário
#[] - cria uma lista - lista que pode ser modificada
#set() - Cria uma lista com valores que não se repetem

#print (len(lista))
#print(lista.count(7))

#print(lista[0])

#lista = set()
#lista.add(10)

#print(lista)


#n1=1
#n2=2
#
#boolean1 = True
#boolean2 = n2 % n1 == 0
#
#if boolean2:
#    print("é divisivel")
#else:
#    print("não é divisivel")
#
#print(boolean1)
#print(boolean2)



#frutas = {
#    "maçã": 1.5,
#    "banana": 3,
#    "goiaba": 2.5
#}
#for i in frutas:
#
#    print(frutas[i])

dici = {"leo":[9, 1], "davi":[5,9,"davi@gmail.com"]}

print(dici["davi"][0])

emailUpper = dici["davi"][2].upper()

dici["davi"] = dici["davi"] + ["985858585"]
dici["davi"].append("84")

dici["carlos"] = []

print(dici)

print()

maior_valor = 0
lista = []
for i in range(10):
  lista = int(input("escreva 10 valores"))
for
# Out:
# 5
# {'leo': [9, 1], 'davi': [5, 9, 'davi@gmail.com', '985858585', '84'], 'carlos': []}
# DAVI@GMAIL.COM
# False

# %%
#numeros = [1,3,5,4,6,7,2,8]
#for i in numeros:
 #   if(valor % 2 != 0):
  #    print(valor)

#for letra in "Estou com sono":
   # print("oi")

#soma = 0
#numeros = range(1,1000)
#i = 0


#while soma < 100:
   # soma = soma + numeros[i]
   # i+=1
  #  print("quantidade de vezes que foi executado",i)
  #  print(soma)

#soma = 0
#x = 0 #quantidade de vezes que está acontecendo o while

#while True:
 # x+= 1
 # if x % 2 == 0:
 #   y =  x
 #   print(y)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# 2424172
# 2424174
# 2424176
# 2424178
# 2424180
# 2424182
# 2424184
# 2424186
# 2424188
# 2424190
# 2424192
# 2424194
# 2424196
# 2424198
# 2424200
# 2424202
# 2424204
# 2424206
# 2424208
# 2424210
# 2424212
# 2424214
# 2424216
# 2424218
# 2424220
# 2424222
# 2424224
# 2424226
# 2424228
# 2424230
# 2424232
# 2424234
# 2424236
# 2424238
# 2424240
# 2424242
# 2424244
# 2424246
# 2424248
# 2424250
# 2424252
# 2424254
# 2424256
# 2424258
# 2424260
# 2424262
# 2424264
# 2424266
# 2424268
# 2424270
# 2424272
# 2424274
# 2424276
# 2424278
# 2424280
# 2424282
# 2424284
# 2424286
# 2424288
# 2424290
# 2424292
# 2424294
# 2424296
# 2424298
# 2424300
# 2424302
# 2424304
# 2424306
# 2424308
# 2424310
# 2424312
# 2424314
# 2424316
# 2424318
# 2424320
# 2424322
# 2424324
# 2424326
# 2424328
# 2424330
# 2424332
# 2424334
# 2424336
# 2424338
# 2424340
# 2424342
# 2424344
# 2424346
# 2424348
# 2424350
# 2424352
# 2424354
# 2424356
# ...

# %% [markdown]
# Lanche
# Façam uma tabela e escreva um programa que leia o código de um item e a quantidade deste item. A seguir, calcule e mostre o valor da conta a pagar.

# %%
n = 4
for i in range(1,11):
    print(f"{n} x {i} = {n*i}")
# Out:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40

# %%
n1=[]

for i in range(10):
 n1.append(int(input("escreva um numero")))
print(n1)

maior_valor=0
for i in n1:
  if i > maior_valor:
    maior_valor = i
print(maior_valor)
# Out:
# escreva um numero10

# %% [markdown]
# Faça um programa que recebe um número de 1 a 10 e imprime a tabuada desse número.
#
# Faça um programa que recebe do usuário 10 valores de números inteiros, armazena em um vetor e após percorrê-lo exibe qual é o maior valor e a sua posição.
#
# lista = []
#
# lista. append(valor)
#
# lista [1,5,20,30,457,4,6,4,]
# maior valor = 0
# posicao = 0
# for i in lista
#   if lista[i] > maior valor
#   maior valor = lista[i]
#   posicao = i
#
# print maior valor , posicao

# %%
arquivo = open("lista_compras.txt","w")

arquivo.write("Arroz\n")
arquivo.write("Feijão\n")
arquivo.write("Macarrão\n")
# Out:
# 9

# %%
from datetime import datetime
import random
alunos = ["ana", "bruno", "carla", "daniel", "eduardo", "fernanda"]
ajudante = random.choice(alunos)
data = datetime.now().strftime("22/08/2026")
print(f"data do sorteio: {data}")
print(f"o aluno ajudante do dia é: {ajudante}")
# Out:
# data do sorteio: 22/08/2026
# o aluno ajudante do dia é: fernanda

# %%
print ("vamos montar sua tabuada!")
numero = int(input("me fala um numero:"))
print(f"\ncerto! tabuada do numero {numero} de 1 a 10:\n")
for i in range (1, 11):
    resultado = numero * i
    dasd
    print(f"{numero} x {i} = {resultado}")
# Out:
# vamos montar sua tabuada!
# me fala um numero:8
#
# certo! tabuada do numero 8 de 1 a 10:
#
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80
